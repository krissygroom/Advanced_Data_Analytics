# %% [markdown]
# ### Exploratory Statistics for Economic Freedom dataset

# %%
# import needed libraries for assignment:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# read in the data as a pandas DataFrame:
bdtable = pd.read_csv("efw_cc.csv")
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
bdtable
# Out:
#       year ISO_code               countries  ECONOMIC FREEDOM   rank  \
# 0     2016      ALB                 Albania              7.54   34.0
# 1     2016      DZA                 Algeria              4.99  159.0
# 2     2016      AGO                  Angola              5.17  155.0
# 3     2016      ARG               Argentina              4.84  160.0
# 4     2016      ARM                 Armenia              7.57   29.0
# 5     2016      AUS               Australia              7.98   10.0
# 6     2016      AUT                 Austria              7.58   27.0
# 7     2016      AZE              Azerbaijan              6.49  106.0
# 8     2016      BHS                 Bahamas              7.34   49.0
# 9     2016      BHR                 Bahrain              7.56   30.0
# 10    2016      BGD              Bangladesh              6.30  120.0
# 11    2016      BRD                Barbados              6.43  111.0
# 12    2016      BLR                 Belarus              6.23  123.0
# ...

# %%
# scatterplot
df = pd.read_csv("economic_freedom_scatter.csv")
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
df
# Out:
#       Unnamed: 0  ECONOMIC.FREEDOM  X1a_government_consumption  X1b_transfers  \
# 0              1              7.54                    8.232353       7.509902
# 1              2              4.99                    2.150000       7.817129
# 2              3              5.17                    7.600000       8.886739
# 3              4              4.84                    5.335294       6.048930
# 4              5              7.57                    7.264706       7.748532
# 5              6              7.98                    4.511765       6.664948
# 6              7              7.58                    3.744118       3.101062
# 7              8              6.49                    6.320588       7.881208
# 8              9              7.34                    7.085294       9.040503
# 9             10              7.56                    3.688235       9.581704
# 10            11              6.30                    9.455882       9.724590
# ...

# %%
df = df.iloc[:, 1:]

# %%
df.head()
# Out:
#    ECONOMIC.FREEDOM  X1a_government_consumption  X1b_transfers  \
# 0              7.54                    8.232353       7.509902
# 1              4.99                    2.150000       7.817129
# 2              5.17                    7.600000       8.886739
# 3              4.84                    5.335294       6.048930
# 4              7.57                    7.264706       7.748532
#
#    X1c_gov_enterprises  X1_size_government  X2b_impartial_courts  \
# 0                    8            7.935564              3.145462
# 1                    0            3.616782              4.327113
# 2                    0            6.496685              1.974566
# 3                    6            5.346056              2.930563
# 4                    8            7.003310              4.197569
#
#    X2d_military_interference  X2f_legal_enforcement_contracts  \
# 0                   8.333333                         4.387444
# 1                   4.166667                         4.507538
# ...

# %%
bdtable.isnull().sum()
# Out:
# year                                     0
# ISO_code                                 0
# countries                                0
# ECONOMIC FREEDOM                       723
# rank                                   723
# quartile                               723
# 1a_government_consumption              589
# 1b_transfers                           960
# 1c_gov_enterprises                     646
# 1d_top_marg_tax_rate                  1047
# 1_size_government                      647
# 2a_judicial_independence              1553
# 2b_impartial_courts                   1179
# 2c_protection_property_rights         1129
# 2d_military_interference              1186
# 2e_integrity_legal_system             1153
# 2f_legal_enforcement_contracts        1361
# 2g_restrictions_sale_real_property    1384
# 2h_reliability_police                 2071
# 2i_business_costs_crime               2071
# 2j_gender_adjustment                    66
# 2_property_rights                      755
# ...

# %%
bdtable
# Out:
#       year ISO_code               countries  ECONOMIC FREEDOM   rank  \
# 0     2016      ALB                 Albania              7.54   34.0
# 1     2016      DZA                 Algeria              4.99  159.0
# 2     2016      AGO                  Angola              5.17  155.0
# 3     2016      ARG               Argentina              4.84  160.0
# 4     2016      ARM                 Armenia              7.57   29.0
# 5     2016      AUS               Australia              7.98   10.0
# 6     2016      AUT                 Austria              7.58   27.0
# 7     2016      AZE              Azerbaijan              6.49  106.0
# 8     2016      BHS                 Bahamas              7.34   49.0
# 9     2016      BHR                 Bahrain              7.56   30.0
# 10    2016      BGD              Bangladesh              6.30  120.0
# 11    2016      BRD                Barbados              6.43  111.0
# 12    2016      BLR                 Belarus              6.23  123.0
# ...

# %%
# size of the data:
bdtable.shape
# Out:
# (3726, 36)

# %%
# viewing basic descriptions of the data:
bdtable.dtypes
# Out:
# year                                    int64
# ISO_code                               object
# countries                              object
# ECONOMIC FREEDOM                      float64
# rank                                  float64
# quartile                              float64
# 1a_government_consumption             float64
# 1b_transfers                          float64
# 1c_gov_enterprises                    float64
# 1d_top_marg_tax_rate                  float64
# 1_size_government                     float64
# 2a_judicial_independence              float64
# 2b_impartial_courts                   float64
# 2c_protection_property_rights         float64
# 2d_military_interference              float64
# 2e_integrity_legal_system             float64
# 2f_legal_enforcement_contracts        float64
# 2g_restrictions_sale_real_property    float64
# 2h_reliability_police                 float64
# 2i_business_costs_crime               float64
# ...

# %%
# checking null values:
bdtable[bdtable.isnull().any(axis=1)]
# Out:
#       year ISO_code               countries  ECONOMIC FREEDOM   rank  \
# 8     2016      BHS                 Bahamas              7.34   49.0
# 11    2016      BRD                Barbados              6.43  111.0
# 12    2016      BLR                 Belarus              6.23  123.0
# 14    2016      BLZ                  Belize              6.86   83.0
# 15    2016      BEN                   Benin              5.98  134.0
# 16    2016      BTN                  Bhutan              7.02   73.0
# 18    2016      BIH  Bosnia and Herzegovina              6.60   98.0
# 21    2016      BRN       Brunei Darussalam              6.93   77.0
# 24    2016      BDI                 Burundi              5.92  138.0
# 25    2016      KHM                Cambodia              7.17   64.0
# 28    2016      CPV              Cape Verde              6.68   93.0
# 29    2016      CAF       Central Afr. Rep.              5.11  156.0
# 30    2016      TCD                    Chad              5.44  150.0
# ...

# %%
# we can see when we try to perform descriptive statistics on all variables, we will get some missing values
# for the categorical attributes, and for some of the numerical values:
bdtable.describe(include="all")
# Out:
#                year ISO_code countries  ECONOMIC FREEDOM         rank  \
# count   3726.000000     3726      3726       3003.000000  3003.000000
# unique          NaN      162       162               NaN          NaN
# top             NaN      KOR   Lesotho               NaN          NaN
# freq            NaN       23        23               NaN          NaN
# mean    2001.347826      NaN       NaN          6.519640    68.307026
# std       12.735125      NaN       NaN          1.133638    41.343417
# min     1970.000000      NaN       NaN          1.970000     1.000000
# 25%     1995.000000      NaN       NaN          5.855000    33.000000
# 50%     2005.000000      NaN       NaN          6.680000    66.000000
# 75%     2011.000000      NaN       NaN          7.350000   102.000000
# max     2016.000000      NaN       NaN          9.190000   162.000000
#
#            quartile  1a_government_consumption  1b_transfers  \
# count   3003.000000                3137.000000   2766.000000
# ...

# %%
bdtable['quartile'].describe()
# Out:
# count    3003.000000
# mean        2.497835
# std         1.118963
# min         1.000000
# 25%         1.000000
# 50%         3.000000
# 75%         3.000000
# max         4.000000
# Name: quartile, dtype: float64

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
bdtable.groupby("year").describe().T
# Out:
# year                                            1970        1975        1980  \
# 1_size_government                  count   90.000000  102.000000  108.000000
#                                    mean     5.961421    5.403670    5.069038
#                                    std      1.792365    1.693317    1.650179
#                                    min      1.743562    1.487284    1.602104
#                                    25%      4.760025    4.347925    4.177393
#                                    50%      5.815076    5.208579    5.014665
#                                    75%      7.254366    6.630889    5.967870
#                                    max      9.645367    9.463235    9.747733
# 1a_government_consumption          count   93.000000  107.000000  113.000000
#                                    mean     6.634156    6.149175    6.050969
#                                    std      1.876248    2.245842    2.243827
# ...

# %%
year_df = bdtable[bdtable["year"] >= 2000]

# %%
year_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2754 entries, 0 to 2753
# Data columns (total 36 columns):
# year                                  2754 non-null int64
# ISO_code                              2754 non-null object
# countries                             2754 non-null object
# ECONOMIC FREEDOM                      2427 non-null float64
# rank                                  2427 non-null float64
# quartile                              2427 non-null float64
# 1a_government_consumption             2468 non-null float64
# 1b_transfers                          2256 non-null float64
# 1c_gov_enterprises                    2456 non-null float64
# 1d_top_marg_tax_rate                  2245 non-null float64
# 1_size_government                     2432 non-null float64
# 2a_judicial_independence              2116 non-null float64
# 2b_impartial_courts                   2425 non-null float64
# 2c_protection_property_rights         2131 non-null float64
# ...

# %%
year_df.isnull().sum()
# Out:
# year                                     0
# ISO_code                                 0
# countries                                0
# ECONOMIC FREEDOM                       327
# rank                                   327
# quartile                               327
# 1a_government_consumption              286
# 1b_transfers                           498
# 1c_gov_enterprises                     298
# 1d_top_marg_tax_rate                   509
# 1_size_government                      322
# 2a_judicial_independence               638
# 2b_impartial_courts                    329
# 2c_protection_property_rights          623
# 2d_military_interference               331
# 2e_integrity_legal_system              602
# 2f_legal_enforcement_contracts         389
# 2g_restrictions_sale_real_property     412
# 2h_reliability_police                 1099
# 2i_business_costs_crime               1099
# 2j_gender_adjustment                    48
# 2_property_rights                      314
# ...

# %%
# size of the data:
year_df.shape
# Out:
# (2754, 36)

# %%
# drop variables with most missing data still > 500 missing values
new_df = year_df.drop(columns=["1d_top_marg_tax_rate", "2a_judicial_independence", "2c_protection_property_rights", 
                              "2e_integrity_legal_system", "2h_reliability_police", "2i_business_costs_crime"])

# %%
new_df.isnull().sum()
# Out:
# year                                    0
# ISO_code                                0
# countries                               0
# ECONOMIC FREEDOM                      327
# rank                                  327
# quartile                              327
# 1a_government_consumption             286
# 1b_transfers                          498
# 1c_gov_enterprises                    298
# 1_size_government                     322
# 2b_impartial_courts                   329
# 2d_military_interference              331
# 2f_legal_enforcement_contracts        389
# 2g_restrictions_sale_real_property    412
# 2j_gender_adjustment                   48
# 2_property_rights                     314
# 3a_money_growth                       319
# 3b_std_inflation                      319
# 3c_inflation                          319
# 3d_freedom_own_foreign_currency       327
# 3_sound_money                         329
# 4a_tariffs                            327
# ...

# %%
new_df.head()
# Out:
#    year ISO_code  countries  ECONOMIC FREEDOM   rank  quartile  \
# 0  2016      ALB    Albania              7.54   34.0       1.0
# 1  2016      DZA    Algeria              4.99  159.0       4.0
# 2  2016      AGO     Angola              5.17  155.0       4.0
# 3  2016      ARG  Argentina              4.84  160.0       4.0
# 4  2016      ARM    Armenia              7.57   29.0       1.0
#
#    1a_government_consumption  1b_transfers  1c_gov_enterprises  \
# 0                   8.232353      7.509902                 8.0
# 1                   2.150000      7.817129                 0.0
# 2                   7.600000      8.886739                 0.0
# 3                   5.335294      6.048930                 6.0
# 4                   7.264706      7.748532                 8.0
#
#    1_size_government  2b_impartial_courts  2d_military_interference  \
# 0           7.935564             3.145462                  8.333333
# ...

# %%
new_df.shape
# Out:
# (2754, 30)

# %%
# now get rid of rows with missing values:
new_df.dropna(axis=0, inplace=True)

# %%
new_df.shape
# Out:
# (2075, 30)

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2075 entries, 0 to 2753
# Data columns (total 30 columns):
# year                                  2075 non-null int64
# ISO_code                              2075 non-null object
# countries                             2075 non-null object
# ECONOMIC FREEDOM                      2075 non-null float64
# rank                                  2075 non-null float64
# quartile                              2075 non-null float64
# 1a_government_consumption             2075 non-null float64
# 1b_transfers                          2075 non-null float64
# 1c_gov_enterprises                    2075 non-null float64
# 1_size_government                     2075 non-null float64
# 2b_impartial_courts                   2075 non-null float64
# 2d_military_interference              2075 non-null float64
# 2f_legal_enforcement_contracts        2075 non-null float64
# 2g_restrictions_sale_real_property    2075 non-null float64
# ...

# %%
new_df.hist(figsize=(14,14));

# %%
# drop rank and quartile b/c will not be using in regression
new_df = new_df.drop(columns=["rank", "quartile"])

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2075 entries, 0 to 2753
# Data columns (total 28 columns):
# year                                  2075 non-null int64
# ISO_code                              2075 non-null object
# countries                             2075 non-null object
# ECONOMIC FREEDOM                      2075 non-null float64
# 1a_government_consumption             2075 non-null float64
# 1b_transfers                          2075 non-null float64
# 1c_gov_enterprises                    2075 non-null float64
# 1_size_government                     2075 non-null float64
# 2b_impartial_courts                   2075 non-null float64
# 2d_military_interference              2075 non-null float64
# 2f_legal_enforcement_contracts        2075 non-null float64
# 2g_restrictions_sale_real_property    2075 non-null float64
# 2j_gender_adjustment                  2075 non-null float64
# 2_property_rights                     2075 non-null float64
# ...

# %%
# create dummy variable for categorical in R

# %%
# save this as dataset to use for regression in r
new_df.to_csv('economic_freedom_edited.csv', index=False)

# %% [markdown]
# ### General Characteristics of numerical data
